# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
digits = load_digits()

# %%
X,y = digits.data , digits.target

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,stratify=y,random_state=26)#86% , 24 .. 88%,26

# %%
tree = DecisionTreeClassifier(max_depth=11,random_state=1)

# %%
tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=11,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=1,
#             splitter='best')

# %%
print("Accuracy on training set: {:.3f}".format(tree.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(tree.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.990
# Accuracy on test set: 0.889

# %%
for i in range(1,42):
    for k in range(0,50):
        tree = DecisionTreeClassifier(max_depth=i,random_state=k)
        tree.fit(X_train,y_train)
        print("At max_depth = " + str(i) +" random_state ="+str(k) +" Accuracy = " + str(tree.score(X_test, y_test)) +"%")
# Out:
# At max_depth = 1 random_state =0 Accuracy = 0.20222222222222222%
# At max_depth = 1 random_state =1 Accuracy = 0.20222222222222222%
# At max_depth = 1 random_state =2 Accuracy = 0.20222222222222222%
# At max_depth = 1 random_state =3 Accuracy = 0.20222222222222222%
# At max_depth = 1 random_state =4 Accuracy = 0.20222222222222222%
# At max_depth = 1 random_state =5 Accuracy = 0.20222222222222222%
# At max_depth = 1 random_state =6 Accuracy = 0.20222222222222222%
# At max_depth = 1 random_state =7 Accuracy = 0.20222222222222222%
# At max_depth = 1 random_state =8 Accuracy = 0.20222222222222222%
# At max_depth = 1 random_state =9 Accuracy = 0.20222222222222222%
# At max_depth = 1 random_state =10 Accuracy = 0.20222222222222222%
# At max_depth = 1 random_state =11 Accuracy = 0.20222222222222222%
# At max_depth = 1 random_state =12 Accuracy = 0.20222222222222222%
# At max_depth = 1 random_state =13 Accuracy = 0.20222222222222222%
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
seen,unseen = [],[]
Max_depth = list(range(1,50))
for i in Max_depth:
    tree = DecisionTreeClassifier(max_depth=i)
    tree.fit(X_train,y_train)
    train_acc = tree.score(X_train,y_train)
    test_acc = tree.score(X_test,y_test)
    seen.append(test_acc)
    unseen.append(train_acc)
plt.plot(Max_depth,seen,label='train')
plt.plot(Max_depth,unseen,label='test')
plt.ylabel("Accurracy")
plt.xlabel("C")
plt.legend()
plt.show()
# Out:
#   File "<ipython-input-11-bcaf107ad062>", line 9
#     test_acc = tree.score(X_test,y_test)
#            ^
# SyntaxError: invalid syntax
